# %%
import vrplib
# Read the downloaded instance and solution
instance = vrplib.read_instance("/Users/alanale/Downloads/A/A-n32-k5.vrp")
solution = vrplib.read_solution("/Users/alanale/Downloads/A/A-n32-k5.sol")

solution.keys()  # List of solution attributes
# Out:
# dict_keys(['routes', 'cost'])

# %%
instance.keys()  # List of instance attributes
# Out:
# dict_keys(['name', 'comment', 'type', 'dimension', 'edge_weight_type', 'capacity', 'node_coord', 'demand', 'depot', 'edge_weight'])

# %%
print("Problem name:", instance.name)
print("Number of nodes:", instance.dimension)
print("Depot ID:", instance.depot)
print("Truck capacity:", getattr(instance, 'capacity', None))

print("\nFirst 5 node coordinates:")
for node, coord in list(instance.node_coords.items())[:5]:
    print(node, coord)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print("Problem name:", instance.name)
#       2 print("Number of nodes:", instance.dimension)
#       3 print("Depot ID:", instance.depot)
#
# AttributeError: 'dict' object has no attribute 'name'
